# %%
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import unicodedata
import numpy as np
import re

import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import plotly.figure_factory as ff

import warnings
warnings.filterwarnings('ignore')

from wordcloud import WordCloud, STOPWORDS

import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

import nltk
from nltk.sentiment import SentimentIntensityAnalyzer
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package punkt to /home/aimfeld/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/aimfeld/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /home/aimfeld/nltk_data...
# True

# %% [markdown]
# Documentation:
#
# * nltk: https://www.nltk.org/
# * Textblob: https://textblob.readthedocs.io/en/dev/
# * wordcloud: https://amueller.github.io/word_cloud/

# %%
data = pd.read_csv('../data/Categories and prompts and ratings.csv')
data.head()
# Out:
#                     Topic  Prompt Nr                      Prompt  Model  \
# 0  Creativity (Christine)        1.0  Write a Haiku about a fork    1.0
# 1                     NaN        NaN                         NaN    2.0
# 2                     NaN        NaN                         NaN    3.0
# 3                     NaN        NaN                         NaN    4.0
# 4                     NaN        NaN                         NaN    5.0
#
#   Actual Model (Fill in after Rating is complete)  \
# 0                                     ChatGPT 3.5
# 1                                       ChatGPT 4
# 2                                          Gemini
# 3                                 Gemini Advanced
# 4                                       LLaMA 70b
#
#                                             Response  Rating Christine  \
# 0  Silver prongs reach out, Guiding food from pla...               8.0
# 1  In hands it dances, Tines whisper through the ...               4.0
# 2  Curved metal tines gleam,  Separates bites, a ...               4.0
# 3  Metal tines curve up, Ready to capture and lif...               8.0
# 4  Tines raised high Food's best friend, a humble...               6.0
#
#      Comments Christine  Rating Ansam  \
# 0  Simple yet efficient           7.0
# 1             Confusing           6.0
# 2             Confusing           9.0
# 3                  Cute          10.0
# 4             Confusing           5.0
#
#                               Comment Ansam  Rating Adrian  \
# 0  Creative, I know what it's talking about            7.0
# 1                     Not bad but too vague            7.0
# 2         Creative, accurate, made me smile            4.0
# 3      Love the use of words to describe it            5.0
# 4             Confusing and trying too hard            3.0
#
#                              Comment Adrian  Rating Mike  \
# 0     Structure matches, feels bland though          8.0
# 1  Structure matches, can't judge it really          4.0
# 2        Structure mismatch, I don't get it          3.0
# 3        Structure matches, but feels basic          9.0
# 4          Structure mismatch, feels clumsy          7.0
#
#                                     Comment Mike  Rating Albin  \
# 0                              Is a Haiku, nice!           8.0
# 1               Not quite Haiku, not so specific           6.0
# 2                      Not quite Haiku, too long           4.0
# 3  Is a Haiku, focuses on fork, really like this           7.0
# 4                  Is a Haiku, like this one too           4.0
#
#                 Comment Albin  Rating Grzegorz  \
# 0  first 2 lines really good.              7.0
# 1                     unclear              6.0
# 2            incorrect format             10.0
# 3                good wording              8.0
# 4            incorrect format              5.0
#
#                              Comment Grzegorz Translation Language  \
# 0                                Nice wording                  NaN
# 1                                     Just ok                  NaN
# 2  The best in this category. Creative, funny                  NaN
# 3                      Nice wording, creative                  NaN
# 4          The worst in this category. Boring                  NaN
#
#   Translation Type
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 220 entries, 0 to 219
# Data columns (total 20 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   Topic                                            6 non-null      object
#  1   Prompt Nr                                        18 non-null     float64
#  2   Prompt                                           18 non-null     object
#  3   Model                                            215 non-null    float64
#  4   Actual Model (Fill in after Rating is complete)  215 non-null    object
#  5   Response                                         215 non-null    object
#  6   Rating Christine                                 215 non-null    float64
#  7   Comments Christine                               145 non-null    object
#  8   Rating Ansam                                     215 non-null    float64
#  9   Comment Ansam                                    175 non-null    object
#  10  Rating Adrian                                    215 non-null    float64
#  11  Comment Adrian                                   111 non-null    object
#  12  Rating Mike                                      211 non-null    float64
#  13  Comment Mike                                     136 non-null    object
#  14  Rating Albin                                     215 non-null    float64
#  15  Comment Albin                                    126 non-null    object
#  16  Rating Grzegorz                                  215 non-null    float64
#  17  Comment Grzegorz                                 136 non-null    object
#  18  Translation Language                             140 non-null    object
#  19  Translation Type                                 140 non-null    object
# dtypes: float64(8), object(12)
# memory usage: 34.5+ KB

# %% [markdown]
# # Data cleaning

# %%
data.columns
# Out:
# Index(['Topic', 'Prompt Nr', 'Prompt', 'Model',
#        'Actual Model (Fill in after Rating is complete)', 'Response',
#        'Rating Christine', 'Comments Christine', 'Rating Ansam',
#        'Comment Ansam', 'Rating Adrian', 'Comment Adrian', 'Rating Mike',
#        'Comment Mike', 'Rating Albin', 'Comment Albin', 'Rating Grzegorz',
#        'Comment Grzegorz', 'Translation Language', 'Translation Type'],
#       dtype='object')

# %%
# filling the empty columns with missing data about topics, pormpt number and prompt
data['Topic'].fillna(method='ffill', inplace=True)
data['Prompt Nr'].fillna(method='ffill', inplace=True)
data['Prompt'].fillna(method='ffill', inplace=True)

# %%
# replace space with _ for column names for easier coding

data.columns = data.columns.str.replace(' ', '_')
data.columns
# Out:
# Index(['Topic', 'Prompt_Nr', 'Prompt', 'Model',
#        'Actual_Model_(Fill_in_after_Rating_is_complete)', 'Response',
#        'Rating_Christine', 'Comments_Christine', 'Rating_Ansam',
#        'Comment_Ansam', 'Rating_Adrian', 'Comment_Adrian', 'Rating_Mike',
#        'Comment_Mike', 'Rating_Albin', 'Comment_Albin', 'Rating_Grzegorz',
#        'Comment_Grzegorz', 'Translation_Language', 'Translation_Type'],
#       dtype='object')

# %%
data['Topic'].unique()
# Out:
# array(['Creativity (Christine)', 'Math (Ansam)',
#        'Theory of Mind (Adrian)', 'Intuitive Physics (Mike)',
#        'Idea Generation (Albin)', 'Translation (Grzegorz)'], dtype=object)

# %%
# edit topic name without our personal names
data['Topic'] = data['Topic'].str.replace(r'\(.*?\)', '', regex=True).str.strip()

# %%
# delete rows where there is no prompt or prompt number 

data = data.dropna(subset=['Model', 'Actual_Model_(Fill_in_after_Rating_is_complete)'], how='all')
data.head(5)
# Out:
#         Topic  Prompt_Nr                      Prompt  Model  \
# 0  Creativity        1.0  Write a Haiku about a fork    1.0
# 1  Creativity        1.0  Write a Haiku about a fork    2.0
# 2  Creativity        1.0  Write a Haiku about a fork    3.0
# 3  Creativity        1.0  Write a Haiku about a fork    4.0
# 4  Creativity        1.0  Write a Haiku about a fork    5.0
#
#   Actual_Model_(Fill_in_after_Rating_is_complete)  \
# 0                                     ChatGPT 3.5
# 1                                       ChatGPT 4
# 2                                          Gemini
# 3                                 Gemini Advanced
# 4                                       LLaMA 70b
#
#                                             Response  Rating_Christine  \
# 0  Silver prongs reach out, Guiding food from pla...               8.0
# 1  In hands it dances, Tines whisper through the ...               4.0
# 2  Curved metal tines gleam,  Separates bites, a ...               4.0
# 3  Metal tines curve up, Ready to capture and lif...               8.0
# 4  Tines raised high Food's best friend, a humble...               6.0
#
#      Comments_Christine  Rating_Ansam  \
# 0  Simple yet efficient           7.0
# 1             Confusing           6.0
# 2             Confusing           9.0
# 3                  Cute          10.0
# 4             Confusing           5.0
#
#                               Comment_Ansam  Rating_Adrian  \
# 0  Creative, I know what it's talking about            7.0
# 1                     Not bad but too vague            7.0
# 2         Creative, accurate, made me smile            4.0
# 3      Love the use of words to describe it            5.0
# 4             Confusing and trying too hard            3.0
#
#                              Comment_Adrian  Rating_Mike  \
# 0     Structure matches, feels bland though          8.0
# 1  Structure matches, can't judge it really          4.0
# 2        Structure mismatch, I don't get it          3.0
# 3        Structure matches, but feels basic          9.0
# 4          Structure mismatch, feels clumsy          7.0
#
#                                     Comment_Mike  Rating_Albin  \
# 0                              Is a Haiku, nice!           8.0
# 1               Not quite Haiku, not so specific           6.0
# 2                      Not quite Haiku, too long           4.0
# 3  Is a Haiku, focuses on fork, really like this           7.0
# 4                  Is a Haiku, like this one too           4.0
#
#                 Comment_Albin  Rating_Grzegorz  \
# 0  first 2 lines really good.              7.0
# 1                     unclear              6.0
# 2            incorrect format             10.0
# 3                good wording              8.0
# 4            incorrect format              5.0
#
#                              Comment_Grzegorz Translation_Language  \
# 0                                Nice wording                  NaN
# 1                                     Just ok                  NaN
# 2  The best in this category. Creative, funny                  NaN
# 3                      Nice wording, creative                  NaN
# 4          The worst in this category. Boring                  NaN
#
#   Translation_Type
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN

# %%
data = data.rename(columns={'Actual_Model_(Fill_in_after_Rating_is_complete)': 'Model_Name'})

# %% [markdown]
# Cleaning for sentiment analysis

# %%
# text cleaning 
def remove_accented_chars(text):
    text = unicodedata.normalize('NFKD', text).encode('ascii', 'ignore').decode('utf-8', 'ignore')
    return text

def remove_special_characters(text, remove_digits=False):
    pattern = r'[^a-zA-Z0-9\s]' if not remove_digits else r'[^a-zA-Z\s]'
    text = re.sub(pattern, '', text) 
    return text

def clean_text(text):
    text = re.sub(r"@[A-Za-z0–9]+", "", text) # Remove @mentions replace with blank
    text = re.sub(r"#", "", text) # Remove the ‘#’ symbol, replace with blank
    text = re.sub(r"RT[\s]+", "", text) # Removing RT, replace with blank
    text = re.sub(r"https?:\/\/\S+", "", text) # Remove the hyperlinks
    text = re.sub(r":", "", text) # Remove :
    return text

def remove_emojis(text):
    emoji_pattern = re.compile("["
    u"\U0001F600-\U0001F64F" # emoticons
    u"\U0001F300-\U0001F5FF" # symbols & pictographs
    u"\U0001F680-\U0001F6FF" # transport & map symbols
    u"\U0001F1E0-\U0001F1FF" # flags (iOS)
    u"\U00002500-\U00002BEF" # chinese char
    u"\U00002702-\U000027B0"
    u"\U00002702-\U000027B0"
    u"\U000024C2-\U0001F251"
    u"\U0001f926-\U0001f937"
    u"\U00010000-\U0010ffff"
    u"\u2640-\u2642"
    u"\u2600-\u2B55"
    u"\u200d"
    u"\u23cf"
    u"\u23e9"
    u"\u231a"
    u"\ufe0f" # dingbats
    u"\u3030"
    "]+", flags=re.UNICODE)
    return emoji_pattern.sub(r'', text)

# %%
def clean_column(df, column_name):
    df[column_name] = df[column_name].apply(remove_accented_chars)
    df[column_name] = df[column_name].apply(remove_special_characters)
    df[column_name] = df[column_name].apply(clean_text)
    df[column_name] = df[column_name].apply(remove_emojis)
    return df

# %%
# this will be used for the word cloud

def remove_stopwords(text, is_lower_case=False, stopwords=None):
    if not stopwords:
        stopwords = nltk.corpus.stopwords.words('english')
    tokens = nltk.word_tokenize(text)
    tokens = [token.strip() for token in tokens]
    
    if is_lower_case:
        filtered_tokens = [token for token in tokens if token not in stopwords]
    else:
        filtered_tokens = [token for token in tokens if token.lower() not in stopwords]
    
    filtered_text = ' '.join(filtered_tokens)    
    return filtered_text

# %%
for colname in ['Comments_Christine', 'Comment_Ansam', 'Comment_Adrian', 'Comment_Mike', 'Comment_Albin', 'Comment_Grzegorz']:
    data[colname] = data[colname].replace(np.nan, 'No comment')
    data = clean_column(data, colname)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 215 entries, 0 to 219
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Topic                 215 non-null    object
#  1   Prompt_Nr             215 non-null    float64
#  2   Prompt                215 non-null    object
#  3   Model                 215 non-null    float64
#  4   Model_Name            215 non-null    object
#  5   Response              215 non-null    object
#  6   Rating_Christine      215 non-null    float64
#  7   Comments_Christine    215 non-null    object
#  8   Rating_Ansam          215 non-null    float64
#  9   Comment_Ansam         215 non-null    object
#  10  Rating_Adrian         215 non-null    float64
#  11  Comment_Adrian        215 non-null    object
#  12  Rating_Mike           211 non-null    float64
#  13  Comment_Mike          215 non-null    object
#  14  Rating_Albin          215 non-null    float64
#  15  Comment_Albin         215 non-null    object
#  16  Rating_Grzegorz       215 non-null    float64
#  17  Comment_Grzegorz      215 non-null    object
#  18  Translation_Language  140 non-null    object
#  19  Translation_Type      140 non-null    object
# dtypes: float64(8), object(12)
# memory usage: 35.3+ KB

# %% [markdown]
# # Calculations

# %% [markdown]
# ### Average rating for each prompt

# %%
data['Average_rating'] = data[['Rating_Christine', 'Rating_Ansam', 'Rating_Adrian', 'Rating_Mike', 'Rating_Albin', 'Rating_Grzegorz']].mean(axis=1)
data.head()
# Out:
#         Topic  Prompt_Nr                      Prompt  Model       Model_Name  \
# 0  Creativity        1.0  Write a Haiku about a fork    1.0      ChatGPT 3.5
# 1  Creativity        1.0  Write a Haiku about a fork    2.0        ChatGPT 4
# 2  Creativity        1.0  Write a Haiku about a fork    3.0           Gemini
# 3  Creativity        1.0  Write a Haiku about a fork    4.0  Gemini Advanced
# 4  Creativity        1.0  Write a Haiku about a fork    5.0        LLaMA 70b
#
#                                             Response  Rating_Christine  \
# 0  Silver prongs reach out, Guiding food from pla...               8.0
# 1  In hands it dances, Tines whisper through the ...               4.0
# 2  Curved metal tines gleam,  Separates bites, a ...               4.0
# 3  Metal tines curve up, Ready to capture and lif...               8.0
# 4  Tines raised high Food's best friend, a humble...               6.0
#
#      Comments_Christine  Rating_Ansam                           Comment_Ansam  \
# 0  Simple yet efficient           7.0  Creative I know what its talking about
# 1             Confusing           6.0                   Not bad but too vague
# 2             Confusing           9.0         Creative accurate made me smile
# 3                  Cute          10.0    Love the use of words to describe it
# 4             Confusing           5.0           Confusing and trying too hard
#
#    Rating_Adrian                          Comment_Adrian  Rating_Mike  \
# 0            7.0    Structure matches feels bland though          8.0
# 1            7.0  Structure matches cant judge it really          4.0
# 2            4.0        Structure mismatch I dont get it          3.0
# 3            5.0       Structure matches but feels basic          9.0
# 4            3.0         Structure mismatch feels clumsy          7.0
#
#                                   Comment_Mike  Rating_Albin  \
# 0                              Is a Haiku nice           8.0
# 1              Not quite Haiku not so specific           6.0
# 2                     Not quite Haiku too long           4.0
# 3  Is a Haiku focuses on fork really like this           7.0
# 4                 Is a Haiku like this one too           4.0
#
#                Comment_Albin  Rating_Grzegorz  \
# 0  first 2 lines really good              7.0
# 1                    unclear              6.0
# 2           incorrect format             10.0
# 3               good wording              8.0
# 4           incorrect format              5.0
#
#                            Comment_Grzegorz Translation_Language  \
# 0                              Nice wording                  NaN
# 1                                   Just ok                  NaN
# 2  The best in this category Creative funny                  NaN
# 3                     Nice wording creative                  NaN
# 4         The worst in this category Boring                  NaN
#
#   Translation_Type  Average_rating
# 0              NaN        7.500000
# 1              NaN        5.500000
# 2              NaN        5.666667
# 3              NaN        7.833333
# 4              NaN        5.000000

# %% [markdown]
# ### Group by topic

# %%
data_gb_topic = data.groupby('Topic').agg({'Average_rating':'mean'}).reset_index()
data_gb_topic
# Out:
#                Topic  Average_rating
# 0         Creativity        6.444444
# 1    Idea Generation        7.166667
# 2  Intuitive Physics        6.666667
# 3               Math        6.082222
# 4     Theory of Mind        7.800000
# 5        Translation        6.457143

# %% [markdown]
# ### Group by Model

# %%
data_gb_model = data.groupby('Model_Name').agg({'Average_rating':'mean'}).reset_index()
data_gb_model
# Out:
#         Model_Name  Average_rating
# 0      ChatGPT 3.5        6.534884
# 1        ChatGPT 4        7.831783
# 2           Gemini        7.127907
# 3  Gemini Advanced        7.125581
# 4        LLaMA 70b        4.319380

# %% [markdown]
# # Visualizations

# %% [markdown]
# How did models in general do in each topic?

# %%
fig = px.bar(data_gb_topic, x='Topic', y='Average_rating', 
             title='Average Rating per Topic',
             color='Topic',
             text_auto='.2f') 
fig.update_traces(textposition="outside", cliponaxis=False)
fig.update_layout(showlegend=False)

fig.show()
# Out:
# <div>                            <div id="bf334ac8-d849-4945-a848-ff0c00936372" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bf334ac8-d849-4945-a848-ff0c00936372")) {                    Plotly.newPlot(                        "bf334ac8-d849-4945-a848-ff0c00936372",                        [{"alignmentgroup":"True","hovertemplate":"Topic=%{x}\u003cbr\u003eAverage_rating=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Creativity","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Creativity","offsetgroup":"Creativity","orientation":"v","showlegend":true,"textposition":"outside","texttemplate":"%{y:.2f}","x":["Creativity"],"xaxis":"x","y":[6.444444444444445],"yaxis":"y","type":"bar","cliponaxis":false},{"alignmentgroup":"True","hovertemplate":"Topic=%{x}\u003cbr\u003eAverage_rating=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Idea Generation","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Idea Generation","offsetgroup":"Idea Generation","orientation":"v","showlegend":true,"textposition":"outside","texttemplate":"%{y:.2f}","x":["Idea Generation"],"xaxis":"x","y":[7.166666666666667],"yaxis":"y","type":"bar","cliponaxis":false},{"alignmentgroup":"True","hovertemplate":"Topic=%{x}\u003cbr\u003eAverage_rating=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Intuitive Physics","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Intuitive Physics","offsetgroup":"Intuitive Physics","orientation":"v","showlegend":true,"textposition":"outside","texttemplate":"%{y:.2f}","x":["Intuitive Physics"],"xaxis":"x","y":[6.666666666666667],"yaxis":"y","type":"bar","cliponaxis":false},{"alignmentgroup":"True","hovertemplate":"Topic=%{x}\u003cbr\u003eAverage_rating=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Math","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Math","offsetgroup":"Math","orientation":"v","showlegend":true,"textposition":"outside","texttemplate":"%{y:.2f}","x":["Math"],"xaxis":"x","y":[6.082222222222223],"yaxis":"y","type":"bar","cliponaxis":false},{"alignmentgroup":"True","hovertemplate":"Topic=%{x}\u003cbr\u003eAverage_rating=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Theory of Mind","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Theory of Mind","offsetgroup":"Theory of Mind","orientation":"v","showlegend":true,"textposition":"outside","texttemplate":"%{y:.2f}","x":["Theory of Mind"],"xaxis":"x","y":[7.8],"yaxis":"y","type":"bar","cliponaxis":false},{"alignmentgroup":"True","hovertemplate":"Topic=%{x}\u003cbr\u003eAverage_rating=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Translation","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Translation","offsetgroup":"Translation","orientation":"v","showlegend":true,"textposition":"outside","texttemplate":"%{y:.2f}","x":["Translation"],"xaxis":"x","y":[6.457142857142857],"yaxis":"y","type":"bar","cliponaxis":false}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#e ...

# %% [markdown]
# The distribution of ratings for each topic

# %%
fig = px.box(data, x='Topic', y='Average_rating', title='Rating Distribution by Topic', color='Topic')
fig.update_layout(showlegend=False)
fig.show()
# Out:
# <div>                            <div id="14333235-db65-41de-878e-4c2b9da1a0bf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("14333235-db65-41de-878e-4c2b9da1a0bf")) {                    Plotly.newPlot(                        "14333235-db65-41de-878e-4c2b9da1a0bf",                        [{"alignmentgroup":"True","hovertemplate":"Topic=%{x}\u003cbr\u003eAverage_rating=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Creativity","marker":{"color":"#636efa"},"name":"Creativity","notched":false,"offsetgroup":"Creativity","orientation":"v","showlegend":true,"x":["Creativity","Creativity","Creativity","Creativity","Creativity","Creativity","Creativity","Creativity","Creativity","Creativity","Creativity","Creativity","Creativity","Creativity","Creativity"],"x0":" ","xaxis":"x","y":[7.5,5.5,5.666666666666667,7.833333333333333,5.0,8.5,5.333333333333333,7.0,4.166666666666667,7.833333333333333,5.0,8.166666666666666,5.833333333333333,5.833333333333333,7.5],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"Topic=%{x}\u003cbr\u003eAverage_rating=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Math","marker":{"color":"#EF553B"},"name":"Math","notched":false,"offsetgroup":"Math","orientation":"v","showlegend":true,"x":["Math","Math","Math","Math","Math","Math","Math","Math","Math","Math","Math","Math","Math","Math","Math"],"x0":" ","xaxis":"x","y":[9.666666666666666,9.0,6.0,8.833333333333334,9.5,1.6666666666666667,7.666666666666667,9.5,9.833333333333334,1.0,2.8333333333333335,3.6666666666666665,5.5,5.4,1.1666666666666667],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"Topic=%{x}\u003cbr\u003eAverage_rating=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Theory of Mind","marker":{"color":"#00cc96"},"name":"Theory of Mind","notched":false,"offsetgroup":"Theory of Mind","orientation":"v","showlegend":true,"x":["Theory of Mind","Theory of Mind","Theory of Mind","Theory of Mind","Theory of Mind","Theory of Mind","Theory of Mind","Theory of Mind","Theory of Mind","Theory of Mind","Theory of Mind","Theory of Mind","Theory of Mind","Theory of Mind","Theory of Mind"],"x0":" ","xaxis":"x","y":[10.0,3.8333333333333335,10.0,9.833333333333334,10.0,8.166666666666666,8.5,7.0,9.833333333333334,6.166666666666667,3.5,1.6666666666666667,9.166666666666666,9.333333333333334,10.0],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"Topic=%{x}\u003cbr\u003eAverage_rating=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Intuitive Physics","marker":{"color":"#ab63fa"},"name":"Intuitive Physics","notched":false,"offsetgroup":"Intuitive Physics","orientation":"v","showlegend":true,"x":["Intuitive Physics","Intuitive Physics","Intuitive Physics","Intuitive Physics","Intuitive Physics","Intuitive Physics","Intuitive Physics","Intuitive Physics","Intuitive Physics","Intuitive Physics","Intuitive Physics","Intuitive Physics","Intuitive Physics","Intuitive Physics","Intuitive Physics"],"x0":" ","xaxis":"x","y":[4.666666666666667,8.666666666666666,6.0,8.0,9.333333333333334,3.0,7.0,6.5,9.0,8.666666666666666,2.3333333333333335,5.0,4.5,9.0,8.333333333333334],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"Topic=%{x}\u003cbr\u003eAverage_rating=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Idea Generation","marker":{"color":"#FFA15A"},"name":"Idea Generation","notched":false,"offsetgroup":"Idea Generation","orientation":"v","showlegend":true,"x":["Idea Generation","Idea Generation","Idea Generation","Idea Generation","Idea Generation","Idea Generation","Idea Generation","Idea Generation","Idea Generation","Idea Generation","Idea Generation","Idea Generation","Idea Gene ...

# %% [markdown]
# How did each model do in each topic?

# %%
fig = px.bar(data_gb_model, x='Model_Name', y='Average_rating', 
             title='Average Rating per Model',
             color='Model_Name',
             text_auto='.2f') 
fig.update_traces(textposition="outside", cliponaxis=False)
fig.update_layout(showlegend=False)

fig.show()
# Out:
# <div>                            <div id="c60df856-e836-4c9a-8bbe-87ff8f70b454" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c60df856-e836-4c9a-8bbe-87ff8f70b454")) {                    Plotly.newPlot(                        "c60df856-e836-4c9a-8bbe-87ff8f70b454",                        [{"alignmentgroup":"True","hovertemplate":"Model_Name=%{x}\u003cbr\u003eAverage_rating=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"ChatGPT 3.5","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"ChatGPT 3.5","offsetgroup":"ChatGPT 3.5","orientation":"v","showlegend":true,"textposition":"outside","texttemplate":"%{y:.2f}","x":["ChatGPT 3.5"],"xaxis":"x","y":[6.534883720930233],"yaxis":"y","type":"bar","cliponaxis":false},{"alignmentgroup":"True","hovertemplate":"Model_Name=%{x}\u003cbr\u003eAverage_rating=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"ChatGPT 4","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"ChatGPT 4","offsetgroup":"ChatGPT 4","orientation":"v","showlegend":true,"textposition":"outside","texttemplate":"%{y:.2f}","x":["ChatGPT 4"],"xaxis":"x","y":[7.831782945736434],"yaxis":"y","type":"bar","cliponaxis":false},{"alignmentgroup":"True","hovertemplate":"Model_Name=%{x}\u003cbr\u003eAverage_rating=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Gemini","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Gemini","offsetgroup":"Gemini","orientation":"v","showlegend":true,"textposition":"outside","texttemplate":"%{y:.2f}","x":["Gemini"],"xaxis":"x","y":[7.127906976744186],"yaxis":"y","type":"bar","cliponaxis":false},{"alignmentgroup":"True","hovertemplate":"Model_Name=%{x}\u003cbr\u003eAverage_rating=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Gemini Advanced","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Gemini Advanced","offsetgroup":"Gemini Advanced","orientation":"v","showlegend":true,"textposition":"outside","texttemplate":"%{y:.2f}","x":["Gemini Advanced"],"xaxis":"x","y":[7.125581395348837],"yaxis":"y","type":"bar","cliponaxis":false},{"alignmentgroup":"True","hovertemplate":"Model_Name=%{x}\u003cbr\u003eAverage_rating=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"LLaMA 70b","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"LLaMA 70b","offsetgroup":"LLaMA 70b","orientation":"v","showlegend":true,"textposition":"outside","texttemplate":"%{y:.2f}","x":["LLaMA 70b"],"xaxis":"x","y":[4.31937984496124],"yaxis":"y","type":"bar","cliponaxis":false}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0 ...

# %% [markdown]
# The distribution of ratings for each model

# %%
fig = px.box(data, x='Model_Name', 
             y='Average_rating', title='Rating Distribution by Model', color='Model_Name')
fig.update_layout(showlegend=False)
fig.show()
# Out:
# <div>                            <div id="d84680ab-6fbb-4714-b33e-909e1226b9cf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d84680ab-6fbb-4714-b33e-909e1226b9cf")) {                    Plotly.newPlot(                        "d84680ab-6fbb-4714-b33e-909e1226b9cf",                        [{"alignmentgroup":"True","hovertemplate":"Model_Name=%{x}\u003cbr\u003eAverage_rating=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"ChatGPT 3.5","marker":{"color":"#636efa"},"name":"ChatGPT 3.5","notched":false,"offsetgroup":"ChatGPT 3.5","orientation":"v","showlegend":true,"x":["ChatGPT 3.5","ChatGPT 3.5","ChatGPT 3.5","ChatGPT 3.5","ChatGPT 3.5","ChatGPT 3.5","ChatGPT 3.5","ChatGPT 3.5","ChatGPT 3.5","ChatGPT 3.5","ChatGPT 3.5","ChatGPT 3.5","ChatGPT 3.5","ChatGPT 3.5","ChatGPT 3.5","ChatGPT 3.5","ChatGPT 3.5","ChatGPT 3.5","ChatGPT 3.5","ChatGPT 3.5","ChatGPT 3.5","ChatGPT 3.5","ChatGPT 3.5","ChatGPT 3.5","ChatGPT 3.5","ChatGPT 3.5","ChatGPT 3.5","ChatGPT 3.5","ChatGPT 3.5","ChatGPT 3.5","ChatGPT 3.5","ChatGPT 3.5","ChatGPT 3.5","ChatGPT 3.5","ChatGPT 3.5","ChatGPT 3.5","ChatGPT 3.5","ChatGPT 3.5","ChatGPT 3.5","ChatGPT 3.5","ChatGPT 3.5","ChatGPT 3.5","ChatGPT 3.5"],"x0":" ","xaxis":"x","y":[7.5,8.5,5.0,9.666666666666666,1.6666666666666667,2.8333333333333335,3.8333333333333335,8.5,1.6666666666666667,6.0,6.5,4.5,8.166666666666666,6.5,6.166666666666667,7.833333333333333,7.166666666666667,4.166666666666667,4.833333333333333,7.5,7.833333333333333,6.0,5.5,5.833333333333333,6.0,3.5,3.8333333333333335,7.166666666666667,9.5,7.666666666666667,7.666666666666667,8.0,9.5,8.166666666666666,7.333333333333333,7.5,9.333333333333334,7.0,6.166666666666667,7.5,8.0,6.833333333333333,6.666666666666667],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"Model_Name=%{x}\u003cbr\u003eAverage_rating=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"ChatGPT 4","marker":{"color":"#EF553B"},"name":"ChatGPT 4","notched":false,"offsetgroup":"ChatGPT 4","orientation":"v","showlegend":true,"x":["ChatGPT 4","ChatGPT 4","ChatGPT 4","ChatGPT 4","ChatGPT 4","ChatGPT 4","ChatGPT 4","ChatGPT 4","ChatGPT 4","ChatGPT 4","ChatGPT 4","ChatGPT 4","ChatGPT 4","ChatGPT 4","ChatGPT 4","ChatGPT 4","ChatGPT 4","ChatGPT 4","ChatGPT 4","ChatGPT 4","ChatGPT 4","ChatGPT 4","ChatGPT 4","ChatGPT 4","ChatGPT 4","ChatGPT 4","ChatGPT 4","ChatGPT 4","ChatGPT 4","ChatGPT 4","ChatGPT 4","ChatGPT 4","ChatGPT 4","ChatGPT 4","ChatGPT 4","ChatGPT 4","ChatGPT 4","ChatGPT 4","ChatGPT 4","ChatGPT 4","ChatGPT 4","ChatGPT 4","ChatGPT 4"],"x0":" ","xaxis":"x","y":[5.5,5.333333333333333,8.166666666666666,9.0,7.666666666666667,3.6666666666666665,9.833333333333334,9.833333333333334,9.333333333333334,8.0,9.0,9.0,8.666666666666666,7.333333333333333,8.666666666666666,5.666666666666667,9.166666666666666,7.833333333333333,7.666666666666667,8.0,9.5,7.333333333333333,6.833333333333333,7.5,9.166666666666666,5.5,5.666666666666667,5.666666666666667,9.833333333333334,8.166666666666666,8.333333333333334,6.5,7.333333333333333,8.666666666666666,9.0,7.6,9.666666666666666,7.833333333333333,8.0,8.0,8.666666666666666,7.166666666666667,7.5],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"Model_Name=%{x}\u003cbr\u003eAverage_rating=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Gemini","marker":{"color":"#00cc96"},"name":"Gemini","notched":false,"offsetgroup":"Gemini","orientation":"v","showlegend":true,"x":["Gemini","Gemini","Gemini","Gemini","Gemini","Gemini","Gemini","Gemini","Gemini","Gemini","Gemini","Gemini","Gemini","Gemini","Gemini","Gemini","Gemini","Gemini","Gemini","Gemini","Gemini","Gemini","Gemini","Gemini","Gemini","Gemini","Gemini","Gemini","Gemini","Gemini","Gemini","Gemini","Gemini", ...

# %% [markdown]
# How did each model do in all topic?

# %%
models = data['Model_Name'].unique()
topics = data['Topic'].unique()

rows = len(models)
fig = make_subplots(rows=rows, cols=1, subplot_titles=models, vertical_spacing=0.05)

colors = ['#7fc97f', '#beaed4', '#fdc086', '#ffff99', '#386cb0', '#f0027f']

for i, model in enumerate(models, start=1):
    model_data = data[data['Model_Name'] == model]
    for j, topic in enumerate(topics):
        avg_rating = model_data[model_data['Topic'] == topic]['Average_rating'].values[0]
        fig.add_trace(go.Bar(x=[topic], y=[avg_rating], name=topic, marker_color=colors[j % len(colors)]), row=i, col=1)
        
        fig.add_annotation(x=topic, y=avg_rating+0.4, text=str(round(avg_rating,2)), showarrow=False, row=i, col=1)

fig.update_layout(height=1000, width=1000, title_text="Model Performance by Topic", showlegend=False)
fig.show()
# Out:
# <div>                            <div id="e97ffceb-9bfb-4860-9e24-c29593c3646c" class="plotly-graph-div" style="height:1000px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e97ffceb-9bfb-4860-9e24-c29593c3646c")) {                    Plotly.newPlot(                        "e97ffceb-9bfb-4860-9e24-c29593c3646c",                        [{"marker":{"color":"#7fc97f"},"name":"Creativity","x":["Creativity"],"y":[7.5],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#beaed4"},"name":"Math","x":["Math"],"y":[9.666666666666666],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#fdc086"},"name":"Theory of Mind","x":["Theory of Mind"],"y":[3.8333333333333335],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#ffff99"},"name":"Intuitive Physics","x":["Intuitive Physics"],"y":[6.0],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#386cb0"},"name":"Idea Generation","x":["Idea Generation"],"y":[8.166666666666666],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#f0027f"},"name":"Translation","x":["Translation"],"y":[7.833333333333333],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#7fc97f"},"name":"Creativity","x":["Creativity"],"y":[5.5],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#beaed4"},"name":"Math","x":["Math"],"y":[9.0],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#fdc086"},"name":"Theory of Mind","x":["Theory of Mind"],"y":[9.833333333333334],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#ffff99"},"name":"Intuitive Physics","x":["Intuitive Physics"],"y":[8.0],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#386cb0"},"name":"Idea Generation","x":["Idea Generation"],"y":[8.666666666666666],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#f0027f"},"name":"Translation","x":["Translation"],"y":[5.666666666666667],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#7fc97f"},"name":"Creativity","x":["Creativity"],"y":[5.666666666666667],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#beaed4"},"name":"Math","x":["Math"],"y":[6.0],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#fdc086"},"name":"Theory of Mind","x":["Theory of Mind"],"y":[10.0],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#ffff99"},"name":"Intuitive Physics","x":["Intuitive Physics"],"y":[8.666666666666666],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#386cb0"},"name":"Idea Generation","x":["Idea Generation"],"y":[5.5],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#f0027f"},"name":"Translation","x":["Translation"],"y":[8.833333333333334],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#7fc97f"},"name":"Creativity","x":["Creativity"],"y":[7.833333333333333],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#beaed4"},"name":"Math","x":["Math"],"y":[8.833333333333334],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#fdc086"},"name":"Theory of Mind","x":["Theory of Mind"],"y":[10.0],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#ffff99"},"name":"Intuitive Physics","x":["Intuitive Physics"],"y":[9.333333333333334],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#386cb0"},"name":"Idea Generation","x":["Idea Generation"],"y":[6.166666666666667],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#f0027f"},"name":"Translation","x":["Translation"],"y":[7.0],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#7fc97f"},"name":"Creativity","x":["Creativity"],"y":[5.0],"type":"bar","xaxis":"x5","yaxis":"y5"},{"marker":{"color":"#beaed4"},"name":"Math","x":["Math"],"y":[9.5],"type":"bar","xaxis":"x5","yaxis":"y5"},{"marker":{"color":"#fdc086"},"name":"Theory of Mind","x":["Theory of Mind"],"y":[10.0],"type":"bar","xaxis": ...

# %% [markdown]
# Average rating by model and topic as grouped box plot

# %%
fig = px.box(data, x='Topic', y='Average_rating', color='Model_Name', title='Average rating by topic')
fig.show()
# Out:
# <div>                            <div id="7b57cf28-1d3c-4ffe-9352-3c0616eb1a11" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7b57cf28-1d3c-4ffe-9352-3c0616eb1a11")) {                    Plotly.newPlot(                        "7b57cf28-1d3c-4ffe-9352-3c0616eb1a11",                        [{"alignmentgroup":"True","hovertemplate":"Model_Name=ChatGPT 3.5\u003cbr\u003eTopic=%{x}\u003cbr\u003eAverage_rating=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"ChatGPT 3.5","marker":{"color":"#636efa"},"name":"ChatGPT 3.5","notched":false,"offsetgroup":"ChatGPT 3.5","orientation":"v","showlegend":true,"x":["Creativity","Creativity","Creativity","Math","Math","Math","Theory of Mind","Theory of Mind","Theory of Mind","Intuitive Physics","Intuitive Physics","Intuitive Physics","Idea Generation","Idea Generation","Idea Generation","Translation","Translation","Translation","Translation","Translation","Translation","Translation","Translation","Translation","Translation","Translation","Translation","Translation","Translation","Translation","Translation","Translation","Translation","Translation","Translation","Translation","Translation","Translation","Translation","Translation","Translation","Translation","Translation"],"x0":" ","xaxis":"x","y":[7.5,8.5,5.0,9.666666666666666,1.6666666666666667,2.8333333333333335,3.8333333333333335,8.5,1.6666666666666667,6.0,6.5,4.5,8.166666666666666,6.5,6.166666666666667,7.833333333333333,7.166666666666667,4.166666666666667,4.833333333333333,7.5,7.833333333333333,6.0,5.5,5.833333333333333,6.0,3.5,3.8333333333333335,7.166666666666667,9.5,7.666666666666667,7.666666666666667,8.0,9.5,8.166666666666666,7.333333333333333,7.5,9.333333333333334,7.0,6.166666666666667,7.5,8.0,6.833333333333333,6.666666666666667],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"Model_Name=ChatGPT 4\u003cbr\u003eTopic=%{x}\u003cbr\u003eAverage_rating=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"ChatGPT 4","marker":{"color":"#EF553B"},"name":"ChatGPT 4","notched":false,"offsetgroup":"ChatGPT 4","orientation":"v","showlegend":true,"x":["Creativity","Creativity","Creativity","Math","Math","Math","Theory of Mind","Theory of Mind","Theory of Mind","Intuitive Physics","Intuitive Physics","Intuitive Physics","Idea Generation","Idea Generation","Idea Generation","Translation","Translation","Translation","Translation","Translation","Translation","Translation","Translation","Translation","Translation","Translation","Translation","Translation","Translation","Translation","Translation","Translation","Translation","Translation","Translation","Translation","Translation","Translation","Translation","Translation","Translation","Translation","Translation"],"x0":" ","xaxis":"x","y":[5.5,5.333333333333333,8.166666666666666,9.0,7.666666666666667,3.6666666666666665,9.833333333333334,9.833333333333334,9.333333333333334,8.0,9.0,9.0,8.666666666666666,7.333333333333333,8.666666666666666,5.666666666666667,9.166666666666666,7.833333333333333,7.666666666666667,8.0,9.5,7.333333333333333,6.833333333333333,7.5,9.166666666666666,5.5,5.666666666666667,5.666666666666667,9.833333333333334,8.166666666666666,8.333333333333334,6.5,7.333333333333333,8.666666666666666,9.0,7.6,9.666666666666666,7.833333333333333,8.0,8.0,8.666666666666666,7.166666666666667,7.5],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"Model_Name=Gemini\u003cbr\u003eTopic=%{x}\u003cbr\u003eAverage_rating=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Gemini","marker":{"color":"#00cc96"},"name":"Gemini","notched":false,"offsetgroup":"Gemini","orientation":"v","showlegend":true,"x":["Creativity","Creativity","Creativity","Math","Math","Math","Theory of Mind","Theory of Mind"," ...

# %%
fig = px.box(data, x='Model_Name', y='Average_rating', color='Topic', title='Average rating by model')
fig.show()
# Out:
# <div>                            <div id="81849da0-172b-4885-84f3-6a0dcad1951c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("81849da0-172b-4885-84f3-6a0dcad1951c")) {                    Plotly.newPlot(                        "81849da0-172b-4885-84f3-6a0dcad1951c",                        [{"alignmentgroup":"True","hovertemplate":"Topic=Creativity\u003cbr\u003eModel_Name=%{x}\u003cbr\u003eAverage_rating=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Creativity","marker":{"color":"#636efa"},"name":"Creativity","notched":false,"offsetgroup":"Creativity","orientation":"v","showlegend":true,"x":["ChatGPT 3.5","ChatGPT 4","Gemini","Gemini Advanced","LLaMA 70b","ChatGPT 3.5","ChatGPT 4","Gemini","Gemini Advanced","LLaMA 70b","ChatGPT 3.5","ChatGPT 4","Gemini","Gemini Advanced","LLaMA 70b"],"x0":" ","xaxis":"x","y":[7.5,5.5,5.666666666666667,7.833333333333333,5.0,8.5,5.333333333333333,7.0,4.166666666666667,7.833333333333333,5.0,8.166666666666666,5.833333333333333,5.833333333333333,7.5],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"Topic=Math\u003cbr\u003eModel_Name=%{x}\u003cbr\u003eAverage_rating=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Math","marker":{"color":"#EF553B"},"name":"Math","notched":false,"offsetgroup":"Math","orientation":"v","showlegend":true,"x":["ChatGPT 3.5","ChatGPT 4","Gemini","Gemini Advanced","LLaMA 70b","ChatGPT 3.5","ChatGPT 4","Gemini","Gemini Advanced","LLaMA 70b","ChatGPT 3.5","ChatGPT 4","Gemini","Gemini Advanced","LLaMA 70b"],"x0":" ","xaxis":"x","y":[9.666666666666666,9.0,6.0,8.833333333333334,9.5,1.6666666666666667,7.666666666666667,9.5,9.833333333333334,1.0,2.8333333333333335,3.6666666666666665,5.5,5.4,1.1666666666666667],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"Topic=Theory of Mind\u003cbr\u003eModel_Name=%{x}\u003cbr\u003eAverage_rating=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Theory of Mind","marker":{"color":"#00cc96"},"name":"Theory of Mind","notched":false,"offsetgroup":"Theory of Mind","orientation":"v","showlegend":true,"x":["LLaMA 70b","ChatGPT 3.5","Gemini Advanced","ChatGPT 4","Gemini","LLaMA 70b","ChatGPT 3.5","Gemini Advanced","ChatGPT 4","Gemini","LLaMA 70b","ChatGPT 3.5","Gemini Advanced","ChatGPT 4","Gemini"],"x0":" ","xaxis":"x","y":[10.0,3.8333333333333335,10.0,9.833333333333334,10.0,8.166666666666666,8.5,7.0,9.833333333333334,6.166666666666667,3.5,1.6666666666666667,9.166666666666666,9.333333333333334,10.0],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"Topic=Intuitive Physics\u003cbr\u003eModel_Name=%{x}\u003cbr\u003eAverage_rating=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Intuitive Physics","marker":{"color":"#ab63fa"},"name":"Intuitive Physics","notched":false,"offsetgroup":"Intuitive Physics","orientation":"v","showlegend":true,"x":["LLaMA 70b","Gemini","ChatGPT 3.5","ChatGPT 4","Gemini Advanced","LLaMA 70b","Gemini","ChatGPT 3.5","ChatGPT 4","Gemini Advanced","LLaMA 70b","Gemini","ChatGPT 3.5","ChatGPT 4","Gemini Advanced"],"x0":" ","xaxis":"x","y":[4.666666666666667,8.666666666666666,6.0,8.0,9.333333333333334,3.0,7.0,6.5,9.0,8.666666666666666,2.3333333333333335,5.0,4.5,9.0,8.333333333333334],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"Topic=Idea Generation\u003cbr\u003eModel_Name=%{x}\u003cbr\u003eAverage_rating=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Idea Generation","marker":{"color":"#FFA15A"},"name":"Idea Generation","notched":false,"offsetgroup":"Idea Generation","orientation":"v","showlegend":true,"x":["Gemini","LLaMA 70b","ChatGPT 3.5","Gemini Advanced","ChatGPT 4","Gemini Advanced","ChatGPT 4","Gemini","LLaMA 70b", ...

# %% [markdown]
# Distribution of Ratings by Reviewer

# %%
ratings_data = data.filter(like='Rating').melt(var_name='Reviewer', value_name='Rating')

# %%
fig = px.box(ratings_data, x='Reviewer', y='Rating', color='Reviewer', 
             title='Distribution of Ratings by Reviewer')

fig.update_layout(showlegend=False)
fig.show()
# Out:
# <div>                            <div id="96f3b69c-2624-41cf-b570-d3844b134ea6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("96f3b69c-2624-41cf-b570-d3844b134ea6")) {                    Plotly.newPlot(                        "96f3b69c-2624-41cf-b570-d3844b134ea6",                        [{"alignmentgroup":"True","hovertemplate":"Reviewer=%{x}\u003cbr\u003eRating=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Rating_Christine","marker":{"color":"#636efa"},"name":"Rating_Christine","notched":false,"offsetgroup":"Rating_Christine","orientation":"v","showlegend":true,"x":["Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christine","Rating_Christi ...

# %% [markdown]
# Analyze if the length of the AI-generated response has any correlation with the rating it receives

# %%
# Calculate the length of each response
data['Response_Length'] = data['Response'].astype(str).apply(len)

# Average the ratings across all reviewers for each response
rating_columns = ['Rating_Christine', 'Rating_Ansam', 'Rating_Adrian', 'Rating_Mike', 'Rating_Albin', 'Rating_Grzegorz']

# Prepare data for plotting
plot_data = data[['Response_Length', 'Average_rating']].dropna()

# Create a scatter plot to visualize the correlation between response length and average rating
fig = px.scatter(plot_data, x='Response_Length', y='Average_rating', trendline='ols',
                 title='Response Length vs. Average Rating',
                 labels={'Response_Length': 'Response Length (characters)', 'Average_rating': 'Average Rating'})

fig.show()
# Out:
# <div>                            <div id="7c3b6623-39c5-41cb-a834-10d1fd57f72a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7c3b6623-39c5-41cb-a834-10d1fd57f72a")) {                    Plotly.newPlot(                        "7c3b6623-39c5-41cb-a834-10d1fd57f72a",                        [{"hovertemplate":"Response Length (characters)=%{x}\u003cbr\u003eAverage Rating=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[81,81,88,69,70,2074,1542,1708,1300,1909,858,984,479,604,665,773,553,1336,476,561,1354,989,1457,1271,676,2853,888,1405,1851,1272,845,1085,511,578,560,1606,1521,869,1799,1077,1025,823,719,830,729,811,1772,1295,1930,1154,999,1074,1278,2113,1317,2248,1581,1791,2555,2358,4990,3735,5353,5323,3316,4551,3072,4511,3879,4223,3658,2871,2961,3091,3134,726,615,510,482,546,497,412,329,701,571,454,479,743,623,470,482,518,503,386,329,696,579,420,456,727,577,486,470,519,510,1112,831,685,636,411,520,730,608,764,473,1202,1527,1458,1619,1277,575,1363,554,725,637,1197,391,1040,472,345,333,630,548,1133,648,726,607,550,474,504,502,352,310,689,575,462,471,751,665,497,478,516,485,353,303,759,631,452,465,726,602,492,472,529,438,2203,1969,2534,1412,1563,2224,735,583,493,496,1289,2136,1494,1172,1294,1335,1227,2471,725,569,1112,343,1914,1020,1354,614,746,1475,1182,397,1914,1680,1289,1245,1914,1703,1282,1060,1983,1743,1391,1520,4076,2238,2241,2952,1855,1553,1190,1029],"xaxis":"x","y":[7.5,5.5,5.666666666666667,7.833333333333333,5.0,8.5,5.333333333333333,7.0,4.166666666666667,7.833333333333333,5.0,8.166666666666666,5.833333333333333,5.833333333333333,7.5,9.666666666666666,9.0,6.0,8.833333333333334,9.5,1.6666666666666667,7.666666666666667,9.5,9.833333333333334,1.0,2.8333333333333335,3.6666666666666665,5.5,5.4,1.1666666666666667,10.0,3.8333333333333335,10.0,9.833333333333334,10.0,8.166666666666666,8.5,7.0,9.833333333333334,6.166666666666667,3.5,1.6666666666666667,9.166666666666666,9.333333333333334,10.0,4.666666666666667,8.666666666666666,6.0,8.0,9.333333333333334,3.0,7.0,6.5,9.0,8.666666666666666,2.3333333333333335,5.0,4.5,9.0,8.333333333333334,5.5,6.333333333333333,8.166666666666666,6.166666666666667,8.666666666666666,5.333333333333333,7.333333333333333,7.833333333333333,8.666666666666666,6.5,7.5,8.5,8.666666666666666,6.166666666666667,6.166666666666667,7.833333333333333,7.166666666666667,4.166666666666667,4.833333333333333,7.5,7.833333333333333,6.0,5.5,5.833333333333333,6.0,3.5,3.8333333333333335,5.666666666666667,9.166666666666666,7.833333333333333,7.666666666666667,8.0,9.5,7.333333333333333,6.833333333333333,7.5,9.166666666666666,5.5,5.666666666666667,8.833333333333334,8.666666666666666,5.5,5.5,5.833333333333333,7.666666666666667,6.666666666666667,6.833333333333333,6.333333333333333,5.0,3.8333333333333335,3.6666666666666665,7.0,8.0,1.0,6.333333333333333,8.5,6.333333333333333,7.833333333333333,7.833333333333333,8.666666666666666,9.666666666666666,6.333333333333333,4.333333333333333,8.666666666666666,8.833333333333334,1.0,2.0,4.666666666666667,4.333333333333333,3.0,3.0,4.5,5.0,1.0,3.1666666666666665,7.166666666666667,9.5,7.666666666666667,7.666666666666667,8.0,9.5,8.166666666666666,7.333333333333333,7.5,9.333333333333334,7.0,6.166666666666667,5.666666666666667,9.833333333333334,8.166666666666666,8.333333333333334,6.5,7.333333333333333,8.666666666666666,9.0,7.6,9.666666666666666,7.833333333333333,8.0,9.0,9.833333333333334,6.5,7.166666666666667,7.166666666666667,8.666666666666666,9.166666666666666,9.0,8.333333333333334,9.833333333333334,8.666666666666666,9.0,9.166666666666666,9.333333333333334,7.833333333333333,8.0,8.0,9.333333333333334,8.166666666666666,8.833333333333334,9.0,9.83333 ...

# %% [markdown]
# # Sentiment Analysis

# %%
sia = SentimentIntensityAnalyzer()

# %%
comment_columns = [col for col in data.columns if 'Comment' in col]
comment_columns
# Out:
# ['Comments_Christine',
#  'Comment_Ansam',
#  'Comment_Adrian',
#  'Comment_Mike',
#  'Comment_Albin',
#  'Comment_Grzegorz']

# %%
for colname in comment_columns:
    data[f'{colname}_Sentiment'] = data[colname].astype(str).apply(lambda x: sia.polarity_scores(x)['compound'])

# %%
viz_data = data.copy(deep=True)

viz_data['all_comments'] = viz_data[['Comments_Christine', 'Comment_Ansam', 'Comment_Adrian', 'Comment_Mike', 'Comment_Albin', 'Comment_Grzegorz']].agg(' '.join, axis=1)

# removing stop words for visualizations only because it reduced the polarity for some text
viz_data['all_comments'] = viz_data['all_comments'].apply(remove_stopwords)

# To join all
text = ''.join([post for post in viz_data['all_comments']])

for word_remove in ['No comment', 'comment', 'commentcomment']:
    text = text.replace(word_remove, '')

# generate word cloud 
stopwords = STOPWORDS
wordcloud = WordCloud(width=1000, height = 600, 
                      max_words = 100,
                      stopwords = stopwords,
                      background_color='black').generate(text)

# Display the generated image:
plt.figure( figsize=(20,10), facecolor='k')
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
# Out:
# (-0.5, 999.5, 599.5, -0.5)

# %% [markdown]
# Correlation between Comment Sentiments and Average Rating

# %%
data.columns
# Out:
# Index(['Topic', 'Prompt_Nr', 'Prompt', 'Model', 'Model_Name', 'Response',
#        'Rating_Christine', 'Comments_Christine', 'Rating_Ansam',
#        'Comment_Ansam', 'Rating_Adrian', 'Comment_Adrian', 'Rating_Mike',
#        'Comment_Mike', 'Rating_Albin', 'Comment_Albin', 'Rating_Grzegorz',
#        'Comment_Grzegorz', 'Translation_Language', 'Translation_Type',
#        'Average_rating', 'Response_Length', 'Comments_Christine_Sentiment',
#        'Comment_Ansam_Sentiment', 'Comment_Adrian_Sentiment',
#        'Comment_Mike_Sentiment', 'Comment_Albin_Sentiment',
#        'Comment_Grzegorz_Sentiment'],
#       dtype='object')

# %%
fig = px.scatter(data, x=f'{comment_columns[0]}_Sentiment', y='Average_rating',
                 title=f'Sentiment vs. Average Rating',
                 labels={f'{comment_columns[0]}_Sentiment': 'Sentiment Score', 'AveragAverage_ratinge_Rating': 'Average Rating'},
                 trendline='ols') 

fig.show()
# Out:
# <div>                            <div id="9e86b45c-b1d6-4295-ace8-a79e11524136" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9e86b45c-b1d6-4295-ace8-a79e11524136")) {                    Plotly.newPlot(                        "9e86b45c-b1d6-4295-ace8-a79e11524136",                        [{"hovertemplate":"Sentiment Score=%{x}\u003cbr\u003eAverage_rating=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[0.4215,-0.2263,-0.2263,0.4588,-0.2263,0.3612,0.6786,0.4215,0.0,0.5106,-0.3412,0.1386,-0.3182,0.4215,-0.2755,0.4215,0.4588,0.0,0.4588,0.4404,-0.3491,0.2263,0.4215,0.4215,-0.2263,0.0,0.5719,0.296,0.0,0.0,0.4215,-0.2263,0.2263,0.2263,0.2263,0.6124,0.4404,-0.0341,0.7003,-0.4767,0.0,0.0,0.0,0.4404,0.4404,-0.5423,0.0,0.0,0.0,0.4404,0.0,0.6597,-0.3089,0.0,0.4939,0.0,0.0,0.4215,0.4215,0.4215,0.7717,0.6908,0.6908,-0.1779,0.0,0.3167,-0.0951,0.4404,0.4215,0.4588,0.4215,0.0,0.4215,0.1779,0.1779,0.4215,0.0,-0.4,-0.296,0.8689,0.6697,-0.296,-0.296,0.0,0.4404,-0.296,-0.296,0.0,0.5279,-0.296,-0.296,0.0,0.0,-0.296,-0.296,0.4404,0.1263,-0.296,-0.296,0.4215,0.4404,-0.296,-0.296,-0.3612,-0.296,-0.296,-0.296,0.0,0.1531,-0.296,-0.296,-0.1779,0.296,-0.296,-0.296,0.6597,-0.2263,-0.296,-0.296,0.4754,0.4927,-0.296,-0.296,0.4215,0.4404,-0.296,-0.296,-0.4404,-0.4767,-0.296,-0.296,0.0,0.1887,-0.296,-0.296,0.4404,0.4927,-0.296,-0.296,0.0,0.5719,-0.296,-0.296,0.4404,0.0516,-0.296,-0.296,0.0,0.5719,-0.296,-0.296,0.4497,0.2766,-0.296,-0.296,0.3182,0.5106,-0.296,-0.296,0.4404,0.4927,-0.296,-0.296,0.1655,-0.3612,-0.296,-0.296,0.4754,0.4927,-0.296,-0.296,0.4404,0.1761,-0.296,-0.296,0.6597,0.4404,-0.296,-0.296,0.4404,0.6249,-0.296,-0.296,0.3612,-0.1027,-0.296,-0.296,0.0,0.1531,-0.296,-0.296,0.4404,0.3732,-0.296,-0.296,0.4404,0.296,-0.296,-0.296,0.4404,0.4404,-0.296,-0.296,0.4404,-0.296,-0.296,-0.296,-0.1548,-0.296,-0.296,-0.296,0.0,-0.1531,-0.296,-0.296],"xaxis":"x","y":[7.5,5.5,5.666666666666667,7.833333333333333,5.0,8.5,5.333333333333333,7.0,4.166666666666667,7.833333333333333,5.0,8.166666666666666,5.833333333333333,5.833333333333333,7.5,9.666666666666666,9.0,6.0,8.833333333333334,9.5,1.6666666666666667,7.666666666666667,9.5,9.833333333333334,1.0,2.8333333333333335,3.6666666666666665,5.5,5.4,1.1666666666666667,10.0,3.8333333333333335,10.0,9.833333333333334,10.0,8.166666666666666,8.5,7.0,9.833333333333334,6.166666666666667,3.5,1.6666666666666667,9.166666666666666,9.333333333333334,10.0,4.666666666666667,8.666666666666666,6.0,8.0,9.333333333333334,3.0,7.0,6.5,9.0,8.666666666666666,2.3333333333333335,5.0,4.5,9.0,8.333333333333334,5.5,6.333333333333333,8.166666666666666,6.166666666666667,8.666666666666666,5.333333333333333,7.333333333333333,7.833333333333333,8.666666666666666,6.5,7.5,8.5,8.666666666666666,6.166666666666667,6.166666666666667,7.833333333333333,7.166666666666667,4.166666666666667,4.833333333333333,7.5,7.833333333333333,6.0,5.5,5.833333333333333,6.0,3.5,3.8333333333333335,5.666666666666667,9.166666666666666,7.833333333333333,7.666666666666667,8.0,9.5,7.333333333333333,6.833333333333333,7.5,9.166666666666666,5.5,5.666666666666667,8.833333333333334,8.666666666666666,5.5,5.5,5.833333333333333,7.666666666666667,6.666666666666667,6.833333333333333,6.333333333333333,5.0,3.8333333333333335,3.6666666666666665,7.0,8.0,1.0,6.333333333333333,8.5,6.333333333333333,7.833333333333333,7.833333333333333,8.666666666666666,9.666666666666666,6.333333333333333,4.333333333333333,8.666666666666666,8.833333333333334,1.0,2.0,4.666666666666667,4.333333333333333,3.0,3.0,4.5,5.0,1.0,3.1666666666666665,7.166666666666667,9.5,7.666666666666667,7.666666666666667,8.0,9.5,8.166666666666666,7.333333333333333,7.5,9.3333333333 ...

# %%
correlation_columns = [f'{col}_Sentiment' for col in comment_columns] + ['Average_rating']
correlation_matrix = data[correlation_columns].corr()

# Use Plotly to create a heatmap
fig = ff.create_annotated_heatmap(
    z=correlation_matrix.values,
    x=correlation_matrix.columns.tolist(),
    y=correlation_matrix.index.tolist(),
    colorscale='Viridis',
    annotation_text=correlation_matrix.round(2).values,
    showscale=True
)

fig.update_layout(title_text='Correlation between Comment Sentiments and Average Rating',
                  xaxis=dict(tickangle=0)
                  )
fig.update_layout(height=1000, width=1700)
fig.show()
# Out:
# <div>                            <div id="338d2eef-9061-4562-8e78-72270357e413" class="plotly-graph-div" style="height:1000px; width:1700px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("338d2eef-9061-4562-8e78-72270357e413")) {                    Plotly.newPlot(                        "338d2eef-9061-4562-8e78-72270357e413",                        [{"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"reversescale":false,"showscale":true,"x":["Comments_Christine_Sentiment","Comment_Ansam_Sentiment","Comment_Adrian_Sentiment","Comment_Mike_Sentiment","Comment_Albin_Sentiment","Comment_Grzegorz_Sentiment","Average_rating"],"y":["Comments_Christine_Sentiment","Comment_Ansam_Sentiment","Comment_Adrian_Sentiment","Comment_Mike_Sentiment","Comment_Albin_Sentiment","Comment_Grzegorz_Sentiment","Average_rating"],"z":[[1.0,0.28684458694369097,0.35152357187887945,0.5678320339937708,0.5052769851078649,0.6045619457700134,0.4756017967814788],[0.28684458694369097,1.0,0.10663398550052292,0.384234796474965,0.24618783445054845,0.4742775092600853,0.5225263245712691],[0.35152357187887945,0.10663398550052292,1.0,0.3199947058702879,0.4033491761481455,0.2334328353430013,0.1786816257692795],[0.5678320339937708,0.384234796474965,0.3199947058702879,1.0,0.4443407957209049,0.5535945652679481,0.48666883185362353],[0.5052769851078649,0.24618783445054845,0.4033491761481455,0.4443407957209049,1.0,0.5057228761479803,0.3290231810031851],[0.6045619457700134,0.4742775092600853,0.2334328353430013,0.5535945652679481,0.5057228761479803,1.0,0.49751974956633777],[0.4756017967814788,0.5225263245712691,0.1786816257692795,0.48666883185362353,0.3290231810031851,0.49751974956633777,1.0]],"type":"heatmap"}],                        {"annotations":[{"font":{"color":"#000000"},"showarrow":false,"text":"1.0","x":"Comments_Christine_Sentiment","xref":"x","y":"Comments_Christine_Sentiment","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"0.29","x":"Comment_Ansam_Sentiment","xref":"x","y":"Comments_Christine_Sentiment","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"0.35","x":"Comment_Adrian_Sentiment","xref":"x","y":"Comments_Christine_Sentiment","yref":"y"},{"font":{"color":"#000000"},"showarrow":false,"text":"0.57","x":"Comment_Mike_Sentiment","xref":"x","y":"Comments_Christine_Sentiment","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"0.51","x":"Comment_Albin_Sentiment","xref":"x","y":"Comments_Christine_Sentiment","yref":"y"},{"font":{"color":"#000000"},"showarrow":false,"text":"0.6","x":"Comment_Grzegorz_Sentiment","xref":"x","y":"Comments_Christine_Sentiment","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"0.48","x":"Average_rating","xref":"x","y":"Comments_Christine_Sentiment","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"0.29","x":"Comments_Christine_Sentiment","xref":"x","y":"Comment_Ansam_Sentiment","yref":"y"},{"font":{"color":"#000000"},"showarrow":false,"text":"1.0","x":"Comment_Ansam_Sentiment","xref":"x","y":"Comment_Ansam_Sentiment","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"0.11","x":"Comment_Adrian_Sentiment","xref":"x","y":"Comment_Ansam_Sentiment","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"0.38","x":"Comment_Mike_Sentiment","xref":"x","y":"Comment_Ansam_Sentiment","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"0.25","x":"Comment_Albin_Sentiment","xref":"x","y":"Comment_Ansam_Sentiment","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"0.47","x":"Comment_Grzegorz_Sentiment ...

# %% [markdown]
# ## Linguistic analysis
#
# Decided not to use it, was just a trial

# %%
# Part-of-Speech Tagging
import spacy

# %%
# !python -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.7.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.7.1/en_core_web_sm-3.7.1-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 3.9 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in /home/aimfeld/miniconda3/envs/hslu-gen-ai/lib/python3.11/site-packages (from en-core-web-sm==3.7.1) (3.7.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /home/aimfeld/miniconda3/envs/hslu-gen-ai/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /home/aimfeld/miniconda3/envs/hslu-gen-ai/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.4)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/aimfeld/miniconda3/envs/hslu-gen-ai/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.7)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/aimfeld/miniconda3/envs/hslu-gen-ai/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.6)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/aimfeld/miniconda3/envs/hslu-gen-ai/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.6)
# Requirement already satisfied: thinc<8.3.0,>=8.1.8 in /home/aimfeld/miniconda3/envs/hslu-gen-ai/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.2.2)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /home/aimfeld/miniconda3/envs/hslu-gen-ai/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.9.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /home/aimfeld/miniconda3/envs/hslu-gen-ai/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/aimfeld/miniconda3/envs/hslu-gen-ai/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /home/aimfeld/miniconda3/envs/hslu-gen-ai/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /home/aimfeld/miniconda3/envs/hslu-gen-ai/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /home/aimfeld/miniconda3/envs/hslu-gen-ai/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (5.2.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/aimfeld/miniconda3/envs/hslu-gen-ai/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.66.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/aimfeld/miniconda3/envs/hslu-gen-ai/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /home/aimfeld/miniconda3/envs/hslu-gen-ai/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.6.4)
# Requirement already satisfied: jinja2 in /home/aimfeld/miniconda3/envs/hslu-gen-ai/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.1.3)
# Requirement already satisfied: setuptools in /home/aimfeld/miniconda3/envs/hslu-gen-ai/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (68.2.2)
# Requirement already satisfied: packaging>=20.0 in /home/aimfeld/miniconda3/envs/hslu-gen-ai/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /home/aimfeld/miniconda3/envs/hslu-gen-ai/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in /home/aimfeld/miniconda3/envs/hslu-gen-ai/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.26.4)
# Requirement already satisfied: annotated-types>=0.4.0 in /home/aimfeld/miniconda3/envs/hslu-gen-ai/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in /home/aimfeld/miniconda3/envs/hslu-gen-ai/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.16.3)
# Requirement already satisfied: typing-extensions>=4.6.1 in /home/aimfeld/miniconda3/envs/hslu-gen-ai/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/aimfeld/miniconda3/envs/hslu-gen-ai/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/aimfeld/miniconda3/envs/hslu-gen-ai/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/aimfeld/miniconda3/envs/hslu-gen-ai/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/aimfeld/miniconda3/envs/hslu-gen-ai/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2024.2.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /home/aimfeld/miniconda3/envs/hslu-gen-ai/lib/python3.11/site-packages (from thinc<8.3.0,>=8.1.8->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /home/aimfeld/miniconda3/envs/hslu-gen-ai/lib/python3.11/site-packages (from thinc<8.3.0,>=8.1.8->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /home/aimfeld/miniconda3/envs/hslu-gen-ai/lib/python3.11/site-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /home/aimfeld/miniconda3/envs/hslu-gen-ai/lib/python3.11/site-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/aimfeld/miniconda3/envs/hslu-gen-ai/lib/python3.11/site-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.1.3)
# Installing collected packages: en-core-web-sm
# Successfully installed en-core-web-sm-3.7.1
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
nlp = spacy.load("en_core_web_sm")

# %%
def analyze_entities(text):
    doc = nlp(text)
    for entity in doc.ents:
        print(entity.text, entity.label_, entity.start_char, entity.end_char)

# %%
data.Response[10]
# Out:
# "As they ascended the winding trail, the sky transformed with capricious abandon, shifting hues from cerulean to ominous gray in the span of mere minutes. Sunlight danced through wisps of cloud, casting fleeting shadows upon the verdant landscape. A gentle breeze whispered secrets through the swaying branches, only to be drowned out by the sudden onslaught of rain that pelted down like a thousand tiny drumbeats. Undeterred, they pressed forward, their spirits buoyed by the ever-changing spectacle unfolding above. Through sunbursts and showers, they traversed the wild terrain, each moment a testament to the unpredictable beauty of nature's whims. And as the sun dipped below the horizon, painting the sky in a riot of fiery hues, they emerged from the forest, hearts full, having journeyed through a kaleidoscope of weather on their unforgettable hike."

# %%
review_text = data.Response[10]
analyze_entities(review_text)
# Out:
# of mere minutes TIME 137 152
# a thousand CARDINAL 388 398
